# %% [markdown]
# # PCA-1 - Intro
#
# Dimension reduction of data

# %% [markdown]
# ## Step 1: Load the Data

# %%
import os
import urllib.request

data_location = "../data/cars/mtcars_header.csv"
data_url = 'https://elephantscale-public.s3.amazonaws.com/data/cars/mtcars_header.csv'

if not os.path.exists (data_location):
    data_location = os.path.basename(data_location)
    if not os.path.exists(data_location):
        print("Downloading : ", data_url)
        urllib.request.urlretrieve(data_url, data_location)
print('data_location:', data_location)
# Out:
# Downloading :  https://elephantscale-public.s3.amazonaws.com/data/cars/mtcars_header.csv
# data_location: mtcars_header.csv

# %%
import pandas as pd
pd.options.display.float_format = '{:,.2f}'.format

dataset = pd.read_csv(data_location)
print ('dataset.shape : ', dataset.shape)
dataset.sample(10)
# dataset
# Out:
# dataset.shape :  (32, 12)
#                   model   mpg  cyl   disp   hp  drat   wt  qsec  vs  am  gear  \
# 15  Lincoln Continental 10.40    8 460.00  215  3.00 5.42 17.82   0   0     3
# 22          AMC Javelin 15.20    8 304.00  150  3.15 3.44 17.30   0   0     3
# 0             Mazda RX4 21.00    6 160.00  110  3.90 2.62 16.46   0   1     4
# 16    Chrysler Imperial 14.70    8 440.00  230  3.23 5.34 17.42   0   0     3
# 5               Valiant 18.10    6 225.00  105  2.76 3.46 20.22   1   0     3
# 12           Merc 450SL 17.30    8 275.80  180  3.07 3.73 17.60   0   0     3
# 23           Camaro Z28 13.30    8 350.00  245  3.73 3.84 15.41   0   0     3
# 9              Merc 280 19.20    6 167.60  123  3.92 3.44 18.30   1   0     4
# 24     Pontiac Firebird 19.20    8 400.00  175  3.08 3.85 17.05   0   0     3
# 1         Mazda RX4 Wag 21.00    6 160.00  110  3.90 2.88 17.02   0   1     4
#
#     carb
# 15     4
# 22     2
# 0      4
# 16     4
# 5      1
# 12     3
# 23     4
# 9      4
# 24     2
# 1      4

# %% [markdown]
# ## Step 2 - Explore Data
#
# As we can see, this data has 12 columns.  We want to plot this data in 2D (X and Y axis).  So we need to reduce the dimensions to 2

# %%
dataset2 = dataset.drop(['model'], axis=1)
dataset2
# Out:
#      mpg  cyl   disp   hp  drat   wt  qsec  vs  am  gear  carb
# 0  21.00    6 160.00  110  3.90 2.62 16.46   0   1     4     4
# 1  21.00    6 160.00  110  3.90 2.88 17.02   0   1     4     4
# 2  22.80    4 108.00   93  3.85 2.32 18.61   1   1     4     1
# 3  21.40    6 258.00  110  3.08 3.21 19.44   1   0     3     1
# 4  18.70    8 360.00  175  3.15 3.44 17.02   0   0     3     2
# 5  18.10    6 225.00  105  2.76 3.46 20.22   1   0     3     1
# 6  14.30    8 360.00  245  3.21 3.57 15.84   0   0     3     4
# 7  24.40    4 146.70   62  3.69 3.19 20.00   1   0     4     2
# 8  22.80    4 140.80   95  3.92 3.15 22.90   1   0     4     2
# 9  19.20    6 167.60  123  3.92 3.44 18.30   1   0     4     4
# 10 17.80    6 167.60  123  3.92 3.44 18.90   1   0     4     4
# 11 16.40    8 275.80  180  3.07 4.07 17.40   0   0     3     3
# 12 17.30    8 275.80  180  3.07 3.73 17.60   0   0     3     3
# 13 15.20    8 275.80  180  3.07 3.78 18.00   0   0     3     3
# 14 10.40    8 472.00  205  2.93 5.25 17.98   0   0     3     4
# 15 10.40    8 460.00  215  3.00 5.42 17.82   0   0     3     4
# 16 14.70    8 440.00  230  3.23 5.34 17.42   0   0     3     4
# 17 32.40    4  78.70   66  4.08 2.20 19.47   1   1     4     1
# 18 30.40    4  75.70   52  4.93 1.61 18.52   1   1     4     2
# 19 33.90    4  71.10   65  4.22 1.83 19.90   1   1     4     1
# 20 21.50    4 120.10   97  3.70 2.46 20.01   1   0     3     1
# 21 15.50    8 318.00  150  2.76 3.52 16.87   0   0     3     2
# 22 15.20    8 304.00  150  3.15 3.44 17.30   0   0     3     2
# 23 13.30    8 350.00  245  3.73 3.84 15.41   0   0     3     4
# 24 19.20    8 400.00  175  3.08 3.85 17.05   0   0     3     2
# 25 27.30    4  79.00   66  4.08 1.94 18.90   1   1     4     1
# 26 26.00    4 120.30   91  4.43 2.14 16.70   0   1     5     2
# 27 30.40    4  95.10  113  3.77 1.51 16.90   1   1     5     2
# 28 15.80    8 351.00  264  4.22 3.17 14.50   0   1     5     4
# 29 19.70    6 145.00  175  3.62 2.77 15.50   0   1     5     6
# 30 15.00    8 301.00  335  3.54 3.57 14.60   0   1     5     8
# 31 21.40    4 121.00  109  4.11 2.78 18.60   1   1     4     2

# %% [markdown]
# ## Step 3 - Scale Data
#
# We need to scale data before PCA
#
# There are 2 options
# 1. Using Standard scaler
# 2. Using built-in pandas functions

# %%
## Option -1 

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler ()

scaled = scaler.fit_transform(dataset2)
scaled_data = pd.DataFrame(scaled, columns = dataset2.columns)
scaled_data.head(10)
# Out:
#     mpg   cyl  disp    hp  drat    wt  qsec    vs    am  gear  carb
# 0  0.15 -0.11 -0.58 -0.54  0.58 -0.62 -0.79 -0.88  1.21  0.43  0.75
# 1  0.15 -0.11 -0.58 -0.54  0.58 -0.36 -0.47 -0.88  1.21  0.43  0.75
# 2  0.46 -1.24 -1.01 -0.80  0.48 -0.93  0.43  1.13  1.21  0.43 -1.14
# 3  0.22 -0.11  0.22 -0.54 -0.98 -0.00  0.90  1.13 -0.83 -0.95 -1.14
# 4 -0.23  1.03  1.06  0.42 -0.85  0.23 -0.47 -0.88 -0.83 -0.95 -0.51
# 5 -0.34 -0.11 -0.05 -0.62 -1.59  0.25  1.35  1.13 -0.83 -0.95 -1.14
# 6 -0.98  1.03  1.06  1.46 -0.73  0.37 -1.14 -0.88 -0.83 -0.95  0.75
# 7  0.73 -1.24 -0.69 -1.25  0.18 -0.03  1.22  1.13 -0.83  0.43 -0.51
# 8  0.46 -1.24 -0.74 -0.77  0.61 -0.07  2.87  1.13 -0.83  0.43 -0.51
# 9 -0.15 -0.11 -0.52 -0.35  0.61  0.23  0.26  1.13 -0.83  0.43  0.75

# %%
## Option 2 

scaled_data = (dataset2 - dataset2.mean()) / dataset2.std()
scaled_data.head(10)
# Out:
#     mpg   cyl  disp    hp  drat    wt  qsec    vs    am  gear  carb
# 0  0.15 -0.10 -0.57 -0.54  0.57 -0.61 -0.78 -0.87  1.19  0.42  0.74
# 1  0.15 -0.10 -0.57 -0.54  0.57 -0.35 -0.46 -0.87  1.19  0.42  0.74
# 2  0.45 -1.22 -0.99 -0.78  0.47 -0.92  0.43  1.12  1.19  0.42 -1.12
# 3  0.22 -0.10  0.22 -0.54 -0.97 -0.00  0.89  1.12 -0.81 -0.93 -1.12
# 4 -0.23  1.01  1.04  0.41 -0.84  0.23 -0.46 -0.87 -0.81 -0.93 -0.50
# 5 -0.33 -0.10 -0.05 -0.61 -1.56  0.25  1.33  1.12 -0.81 -0.93 -1.12
# 6 -0.96  1.01  1.04  1.43 -0.72  0.36 -1.12 -0.87 -0.81 -0.93  0.74
# 7  0.72 -1.22 -0.68 -1.24  0.17 -0.03  1.20  1.12 -0.81  0.42 -0.50
# 8  0.45 -1.22 -0.73 -0.75  0.60 -0.07  2.83  1.12 -0.81  0.42 -0.50
# 9 -0.15 -0.10 -0.51 -0.35  0.60  0.23  0.25  1.12 -0.81  0.42  0.74

# %% [markdown]
# ## Step 4 - PCA

# %%
from sklearn.decomposition import PCA

# we are doing 2 PC
pca = PCA(n_components = 2)
pca_data = pca.fit_transform(scaled_data)
pca_df = pd.DataFrame(pca_data, columns = ['pc1', 'pc2'])
pca_df.head(10)
# Out:
#     pc1   pc2
# 0  0.65  1.71
# 1  0.62  1.53
# 2  2.74 -0.14
# 3  0.31 -2.33
# 4 -1.94 -0.74
# 5  0.06 -2.74
# 6 -2.96  0.33
# 7  2.02 -1.44
# 8  2.25 -1.95
# 9  0.52 -0.16

# %% [markdown]
# ## Step 5 - Plot
#
# Now let's plot the reduced data

# %%
import matplotlib.pyplot as plt

plt.scatter(pca_df['pc1'], pca_df['pc2'], marker='o')
plt.show()

# %% [markdown]
# ## Step 6 - Compare Correlation Matrices
#
# Now let's compare correlation matrix of original data and PCA data.
#
# TODO: Can you explain the difference?

# %%
# original data
scaled_data.corr()
# Out:
#        mpg   cyl  disp    hp  drat    wt  qsec    vs    am  gear  carb
# mpg   1.00 -0.85 -0.85 -0.78  0.68 -0.87  0.42  0.66  0.60  0.48 -0.55
# cyl  -0.85  1.00  0.90  0.83 -0.70  0.78 -0.59 -0.81 -0.52 -0.49  0.53
# disp -0.85  0.90  1.00  0.79 -0.71  0.89 -0.43 -0.71 -0.59 -0.56  0.39
# hp   -0.78  0.83  0.79  1.00 -0.45  0.66 -0.71 -0.72 -0.24 -0.13  0.75
# drat  0.68 -0.70 -0.71 -0.45  1.00 -0.71  0.09  0.44  0.71  0.70 -0.09
# wt   -0.87  0.78  0.89  0.66 -0.71  1.00 -0.17 -0.55 -0.69 -0.58  0.43
# qsec  0.42 -0.59 -0.43 -0.71  0.09 -0.17  1.00  0.74 -0.23 -0.21 -0.66
# vs    0.66 -0.81 -0.71 -0.72  0.44 -0.55  0.74  1.00  0.17  0.21 -0.57
# am    0.60 -0.52 -0.59 -0.24  0.71 -0.69 -0.23  0.17  1.00  0.79  0.06
# gear  0.48 -0.49 -0.56 -0.13  0.70 -0.58 -0.21  0.21  0.79  1.00  0.27
# carb -0.55  0.53  0.39  0.75 -0.09  0.43 -0.66 -0.57  0.06  0.27  1.00

# %%
# pca
pca_df.corr()
# Out:
#       pc1   pc2
# pc1  1.00 -0.00
# pc2 -0.00  1.00

# %% [markdown]
# ## Step 7 - Understanding PCA
#
# [SKLearn PCA reference](https://scikit-learn.org/stable/modules/generated/sklearn.decomposition.PCA.html?highlight=pca#sklearn.decomposition.PCA)
#
# * `pca.components_`  : Principal axes in feature space, representing the directions of maximum variance in the data. The components are sorted by explained_variance_
# * `pca.explained_variance_ratio_` : Percentage of variance explained by each of the selected components.

# %%
print ('\n number of columns in original data : ', scaled_data.shape[1])
print ('\n each pca component length : ',  len(pca.components_[0]))
print ('\n pca.components_ :\n',  pca.components_)
print ('\n pca.explained_variance_ratio_ : ' , pca.explained_variance_ratio_)
# Out:
#  number of columns in original data :  11
#
#  each pca component length :  11
#
#  pca.components_ :
#  [[ 0.3625305  -0.37391603 -0.3681852  -0.33005692  0.29415138 -0.34610332
#    0.20045635  0.30651132  0.23494289  0.20691624 -0.21401766]
#  [ 0.0161244   0.04374371 -0.04932413  0.24878402  0.27469408 -0.14303825
#   -0.46337482 -0.23164699  0.42941765  0.46234863  0.41357106]]
#
#  pca.explained_variance_ratio_ :  [0.60076366 0.24095163]

# %% [markdown]
# ## Step 8 - Find 3 Principal Components

# %%
## TODO - you code goes here
## Adjust your code from step-4

pca = PCA(n_components = 4)

pca_data4 = pca.fit_transform(scaled_data)
pca_df4 = pd.DataFrame(pca_data4, columns = ['pc1', 'pc2', 'pc3', 'pc4'])
pca_df4.head(10)
# Out:
#     pc1   pc2   pc3   pc4
# 0  0.65  1.71 -0.59  0.11
# 1  0.62  1.53 -0.38  0.20
# 2  2.74 -0.14 -0.24 -0.25
# 3  0.31 -2.33 -0.13 -0.50
# 4 -1.94 -0.74 -1.12  0.07
# 5  0.06 -2.74  0.16 -0.98
# 6 -2.96  0.33 -0.36 -0.05
# 7  2.02 -1.44  0.93 -0.14
# 8  2.25 -1.95  1.77  0.29
# 9  0.52 -0.16  1.47  0.07

# %% [markdown]
# Let's do a cool 3D plot using plotly
#
# If plotly is missing, you can install it like below

# %%
# ! conda install -y plotly
# ! jupyter labextension install jupyterlab-plotly

# %%
import plotly.express as px

fig = px.scatter_3d(pca_data4, x=0, y=1, z=2,labels={'0': 'PC 1', '1': 'PC 2', '2': 'PC 3'})
fig.show()
#plt.scatter(pca_df_3['pc1'],pca_df_3['pc2'],pca_df_3['pc3'],marker='X')
#plt.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="70efd4de-7a5d-4176-a510-ad80ed0d3f32" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("70efd4de-7a5d-4176-a510-ad80ed0d3f32")) {                    Plotly.newPlot(                        "70efd4de-7a5d-4176-a510-ad80ed0d3f32",                        [{"hovertemplate":"PC 1=%{x}<br>PC 2=%{y}<br>PC 3=%{z}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","scene":"scene","showlegend":false,"x":[0.646862741991578,0.6194831460326777,2.7356242748053368,0.3068606268435133,-1.943392684441435,0.05525342281485908,-2.9553851233225967,2.022959324400315,2.2513839535375175,0.5180912217284059,0.5011860078799704,-2.2124096339436754,-2.0155715693152594,-2.1147047371585375,-3.838372511759314,-3.8918495626124474,-3.5363862157764387,3.7955510830637373,4.187035678355392,4.167535934377671,1.8741790870013417,-2.150441494237805,-1.8340369796886558,-2.8434957523040736,-2.210547914845272,3.5176818133858454,2.609500396505614,3.3323844512235494,-1.3513346957077383,0.0009743304537414562,-2.62708976050828,2.382471141220458],"y":[1.708114157382,1.525621939174728,-0.14415006859696688,-2.3258038090332143,-0.7425211007741589,-2.742122852100614,0.3296132730766645,-1.4421056488482542,-1.9522878973105533,-0.15946104182836202,-0.3187934413076144,-0.6727099371897802,-0.6724606281325062,-0.7891128839292234,-0.8149087065459333,-0.7218314282684803,-0.4145024116075634,-0.2920783394572937,0.6775721481951821,-0.2748889542112979,-2.086452945087116,-0.9982442260212888,-0.8921886098782763,0.6701037062962464,-0.8600504473909683,-0.11929498025151206,2.0141425449713823,1.3568876743780374,3.444878041939464,3.168374970712421,4.310701580744227,0.2299603209006264],"z":[-0.591730913752819,-0.37630126538676667,-0.23743906035625614,-0.13362125717305778,-1.1165366001615769,0.16124557660797828,-0.35704614142044117,0.9290294566098027,1.7689363697129334,1.4692603018851957,1.6570700616094471,-0.3694707440361544,-0.4768341461549102,-0.2904619864076364,0.6370971970622406,0.7092611837245594,0.5402467760778928,-0.41616808034811326,-0.2035830640032773,-0.45891241513723896,0.15432654171103247,-1.1503639499976739,-0.9472872335147378,-0.1605592520803887,-1.0279576849479943,-0.4464715848858052,-0.8172518802057464,-0.44671672975504256,-0.13439433945865406,0.39576101209374637,1.3315940460600997,0.40527980602936253],"type":"scatter3d"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[ ...
