# %%
import random
import copy
import pickle
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import sklearn
from sklearn import metrics
import xgboost as xgb
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import roc_auc_score
import warnings
warnings.filterwarnings("ignore")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Loading the merged train and test dataset

train_data = pd.read_pickle('/content/drive/My Drive/Colab Notebooks/ieee-fraud-detection/Data/train_fe.pkl')
test_data = pd.read_pickle('/content/drive/My Drive/Colab Notebooks/ieee-fraud-detection/Data/test_fe.pkl')

# %%
train_data["card3_FE"]
# Out:
# 0         0.882729
# 1         0.882729
# 2         0.882729
# 3         0.882729
# 4         0.882729
#             ...
# 590535    0.882729
# 590536    0.882729
# 590537    0.882729
# 590538    0.882729
# 590539    0.882729
# Name: card3_FE, Length: 590540, dtype: float64

# %%
def hyperparam_vs_auc(train_roc_auc, cv_roc_auc):
    
    '''
        Utility Function to plot the Training and Cross Validation ROC-AUC Values
        for different Hyperparameter.
    '''
    
    plt.plot(range(len(train_roc_auc)), train_roc_auc, label='Train AUC')
    plt.plot(range(len(cv_roc_auc)), cv_roc_auc, label='CV AUC')

    plt.scatter(range(len(train_roc_auc)), train_roc_auc, label='Train AUC points')
    plt.scatter(range(len(cv_roc_auc)), cv_roc_auc, label='CV AUC points')
    
    plt.xticks(range(len(train_roc_auc)))
    plt.legend()
    plt.xlabel("Hyperparameter Index")
    plt.ylabel("AUC")
    plt.title("\n Hyperparameter vs ROC-AUC \n")
    plt.grid()
    plt.show()

# %%
X_train = train_data.drop(['isFraud'], axis=1)
y_train = train_data['isFraud']

X_test = test_data

del train_data, test_data

# %%
# Hyperparameters

learning_rate = [2e-2, 3e-1, 1e-1]
max_depth = [8, 12, 16]
subsample = [0.6,0.8,1]
colsample_bytree = [0.6,0.8,1]

# %%
results = {}

dtrain = xgb.DMatrix(X_train, label=y_train)

for rate in learning_rate:
  for depth in max_depth:
    for sample in subsample:
      for colsample in colsample_bytree:

        params = {
          'objective' : 'binary:logistic',
          'eval_metric' : 'auc',
          'learning_rate' : rate,
          'max_depth' : depth,
          'subsample' : sample,
          'colsample_bytree' : colsample,
          'tree_method' : 'gpu_hist',
          'random_state' : 3,
        }

        history = xgb.cv(
            params,
            dtrain,
            num_boost_round = 3000,
            nfold = 3,
            metrics ='auc',
            early_stopping_rounds = 100,
            verbose_eval=100,
            seed=3,
            shuffle = False
        )

        name = "learning_rate : "+str(rate)+" max_depth : "+str(depth)+" subsample : "+str(sample)+" colsample_bytree : "+str(colsample)
        results[name] = (history.iloc[-1]['train-auc-mean'],history.iloc[-1]['test-auc-mean'])
# Out:
# [0]	train-auc:0.81863+0.00087	test-auc:0.80471+0.00660
# [100]	train-auc:0.89960+0.00424	test-auc:0.86987+0.00717
# [200]	train-auc:0.94470+0.00145	test-auc:0.89431+0.01057
# [300]	train-auc:0.96862+0.00108	test-auc:0.90968+0.01142
# [400]	train-auc:0.97847+0.00103	test-auc:0.91551+0.01259
# [500]	train-auc:0.98393+0.00079	test-auc:0.91827+0.01277
# [600]	train-auc:0.98765+0.00062	test-auc:0.91972+0.01321
# [700]	train-auc:0.99046+0.00044	test-auc:0.92095+0.01301
# [800]	train-auc:0.99252+0.00024	test-auc:0.92129+0.01355
# [900]	train-auc:0.99412+0.00015	test-auc:0.92159+0.01338
# [1000]	train-auc:0.99537+0.00014	test-auc:0.92142+0.01373
# [1054]	train-auc:0.99597+0.00013	test-auc:0.92147+0.01347
# [0]	train-auc:0.80739+0.00603	test-auc:0.78052+0.02079
# [100]	train-auc:0.89907+0.00485	test-auc:0.86912+0.00646
# [200]	train-auc:0.94556+0.00215	test-auc:0.89491+0.01095
# [300]	train-auc:0.96951+0.00149	test-auc:0.91041+0.01247
# [400]	train-auc:0.97888+0.00111	test-auc:0.91639+0.01249
# [500]	train-auc:0.98423+0.00080	test-auc:0.91930+0.01313
# [600]	train-auc:0.98790+0.00050	test-auc:0.92073+0.01328
# [700]	train-auc:0.99072+0.00027	test-auc:0.92179+0.01339
# [800]	train-auc:0.99275+0.00019	test-auc:0.92191+0.01352
# [879]	train-auc:0.99406+0.00019	test-auc:0.92178+0.01358
# [0]	train-auc:0.81675+0.01266	test-auc:0.80074+0.01033
# [100]	train-auc:0.89840+0.00564	test-auc:0.86882+0.00500
# [200]	train-auc:0.94622+0.00185	test-auc:0.89552+0.01066
# [300]	train-auc:0.96989+0.00121	test-auc:0.91138+0.01173
# [400]	train-auc:0.97909+0.00108	test-auc:0.91716+0.01223
# [500]	train-auc:0.98438+0.00081	test-auc:0.92005+0.01240
# [600]	train-auc:0.98810+0.00062	test-auc:0.92103+0.01260
# [700]	train-auc:0.99085+0.00044	test-auc:0.92186+0.01314
# [800]	train-auc:0.99289+0.00030	test-auc:0.92222+0.01337
# [900]	train-auc:0.99455+0.00022	test-auc:0.92270+0.01345
# [1000]	train-auc:0.99578+0.00017	test-auc:0.92263+0.01341
# [1003]	train-auc:0.99581+0.00017	test-auc:0.92257+0.01346
# [0]	train-auc:0.81979+0.00077	test-auc:0.80534+0.00513
# [100]	train-auc:0.89934+0.00379	test-auc:0.86948+0.00737
# [200]	train-auc:0.94593+0.00161	test-auc:0.89547+0.01095
# [300]	train-auc:0.97026+0.00083	test-auc:0.91143+0.01163
# [400]	train-auc:0.97944+0.00063	test-auc:0.91784+0.01156
# [500]	train-auc:0.98433+0.00058	test-auc:0.92018+0.01199
# [600]	train-auc:0.98784+0.00032	test-auc:0.92161+0.01192
# [700]	train-auc:0.99038+0.00018	test-auc:0.92232+0.01213
# [799]	train-auc:0.99243+0.00011	test-auc:0.92231+0.01260
# [0]	train-auc:0.80625+0.00652	test-auc:0.78794+0.01059
# [100]	train-auc:0.89847+0.00529	test-auc:0.86888+0.00631
# [200]	train-auc:0.94639+0.00187	test-auc:0.89556+0.01105
# [300]	train-auc:0.97088+0.00100	test-auc:0.91143+0.01175
# [400]	train-auc:0.97998+0.00077	test-auc:0.91750+0.01158
# [500]	train-auc:0.98481+0.00078	test-auc:0.92018+0.01189
# [600]	train-auc:0.98816+0.00044	test-auc:0.92159+0.01207
# [700]	train-auc:0.99069+0.00026	test-auc:0.92220+0.01244
# [800]	train-auc:0.99278+0.00009	test-auc:0.92238+0.01308
# [900]	train-auc:0.99426+0.00008	test-auc:0.92240+0.01337
# [938]	train-auc:0.99477+0.00005	test-auc:0.92242+0.01309
# [0]	train-auc:0.80741+0.00529	test-auc:0.79136+0.00139
# [100]	train-auc:0.89753+0.00517	test-auc:0.86781+0.00596
# [200]	train-auc:0.94700+0.00153	test-auc:0.89540+0.01070
# [300]	train-auc:0.97135+0.00118	test-auc:0.91066+0.01184
# [400]	train-auc:0.98022+0.00074	test-auc:0.91722+0.01134
# [500]	train-auc:0.98503+0.00059	test-auc:0.92005+0.01150
# [600]	train-auc:0.98844+0.00044	test-auc:0.92086+0.01177
# [700]	train-auc:0.99100+0.00027	test-auc:0.92176+0.01191
# [800]	train-auc:0.99295+0.00015	test-auc:0.92211+0.01201
# [870]	train-auc:0.99401+0.00016	test-auc:0.92198+0.01204
# [0]	train-auc:0.81202+0.01167	test-auc:0.79971+0.01187
# [100]	train-auc:0.90033+0.00336	test-auc:0.86977+0.00776
# [200]	train-auc:0.94712+0.00154	test-auc:0.89490+0.01257
# [300]	train-auc:0.97069+0.00091	test-auc:0.90953+0.01318
# [400]	train-auc:0.97887+0.00067	test-auc:0.91617+0.01193
# [500]	train-auc:0.98315+0.00048	test-auc:0.91881+0.01196
# [600]	train-auc:0.98636+0.00052	test-auc:0.92034+0.01165
# [700]	train-auc:0.98875+0.00046	test-auc:0.92092+0.01176
# [800]	train-auc:0.99070+0.00041	test-auc:0.92131+0.01175
# [900]	train-auc:0.99226+0.00014	test-auc:0.92132+0.01198
# [962]	train-auc:0.99302+0.00013	test-auc:0.92115+0.01217
# [0]	train-auc:0.81503+0.00783	test-auc:0.80267+0.01077
# [100]	train-auc:0.89850+0.00541	test-auc:0.86883+0.00593
# [200]	train-auc:0.94655+0.00190	test-auc:0.89418+0.01198
# [300]	train-auc:0.97063+0.00126	test-auc:0.90981+0.01217
# [400]	train-auc:0.97849+0.00081	test-auc:0.91565+0.01197
# [500]	train-auc:0.98295+0.00073	test-auc:0.91808+0.01200
# [600]	train-auc:0.98602+0.00071	test-auc:0.91939+0.01207
# [700]	train-auc:0.98855+0.00070	test-auc:0.91969+0.01247
# [800]	train-auc:0.99044+0.00065	test-auc:0.91942+0.01305
# [830]	train-auc:0.99100+0.00058	test-auc:0.91949+0.01316
# [0]	train-auc:0.80988+0.00532	test-auc:0.79569+0.00302
# [100]	train-auc:0.89509+0.00629	test-auc:0.86473+0.00624
# [200]	train-auc:0.94603+0.00153	test-auc:0.89217+0.01289
# [300]	train-auc:0.97023+0.00123	test-auc:0.90840+0.01332
# [400]	train-auc:0.97839+0.00077	test-auc:0.91388+0.01270
# [500]	train-auc:0.98291+0.00051	test-auc:0.91695+0.01239
# [600]	train-auc:0.98592+0.00043	test-auc:0.91773+0.01285
# [682]	train-auc:0.98808+0.00046	test-auc:0.91746+0.01320
# [0]	train-auc:0.85350+0.00336	test-auc:0.82496+0.01463
# [100]	train-auc:0.93957+0.00433	test-auc:0.88938+0.00991
# [200]	train-auc:0.98386+0.00063	test-auc:0.91170+0.01566
# [300]	train-auc:0.99605+0.00026	test-auc:0.91948+0.01764
# [400]	train-auc:0.99858+0.00007	test-auc:0.92184+0.01696
# [500]	train-auc:0.99938+0.00003	test-auc:0.92200+0.01706
# [560]	train-auc:0.99959+0.00003	test-auc:0.92168+0.01673
# [0]	train-auc:0.84961+0.00184	test-auc:0.81313+0.02245
# [100]	train-auc:0.93695+0.00430	test-auc:0.88645+0.00920
# [200]	train-auc:0.98442+0.00059	test-auc:0.91179+0.01563
# [300]	train-auc:0.99633+0.00031	test-auc:0.91974+0.01787
# [400]	train-auc:0.99870+0.00014	test-auc:0.92172+0.01744
# [500]	train-auc:0.99943+0.00006	test-auc:0.92195+0.01691
# [569]	train-auc:0.99966+0.00004	test-auc:0.92133+0.01691
# [0]	train-auc:0.85177+0.00679	test-auc:0.82937+0.00227
# [100]	train-auc:0.93686+0.00465	test-auc:0.88588+0.00830
# [200]	train-auc:0.98536+0.00051	test-auc:0.91130+0.01597
# [300]	train-auc:0.99660+0.00027	test-auc:0.91963+0.01771
# [400]	train-auc:0.99881+0.00014	test-auc:0.92146+0.01736
# [500]	train-auc:0.99947+0.00007	test-auc:0.92158+0.01671
# [556]	train-auc:0.99965+0.00004	test-auc:0.92116+0.01652
# [0]	train-auc:0.85736+0.00101	test-auc:0.83046+0.00932
# [100]	train-auc:0.94079+0.00477	test-auc:0.88958+0.00953
# [200]	train-auc:0.98589+0.00051	test-auc:0.91330+0.01550
# [300]	train-auc:0.99700+0.00025	test-auc:0.91961+0.01810
# [400]	train-auc:0.99901+0.00007	test-auc:0.92169+0.01754
# [500]	train-auc:0.99954+0.00004	test-auc:0.92205+0.01654
# [596]	train-auc:0.99976+0.00003	test-auc:0.92146+0.01630
# [0]	train-auc:0.85215+0.00254	test-auc:0.81560+0.02582
# [100]	train-auc:0.93876+0.00444	test-auc:0.88724+0.00930
# [200]	train-auc:0.98650+0.00100	test-auc:0.91267+0.01633
# [300]	train-auc:0.99724+0.00039	test-auc:0.91970+0.01795
# [400]	train-auc:0.99907+0.00011	test-auc:0.92181+0.01738
# [500]	train-auc:0.99956+0.00004	test-auc:0.92210+0.01650
# [598]	train-auc:0.99978+0.00003	test-auc:0.92177+0.01603
# [0]	train-auc:0.85413+0.00587	test-auc:0.83088+0.00331
# [100]	train-auc:0.93594+0.00458	test-auc:0.88393+0.00960
# [200]	train-auc:0.98690+0.00124	test-auc:0.91211+0.01612
# [300]	train-auc:0.99747+0.00043	test-auc:0.91932+0.01822
# [400]	train-auc:0.99912+0.00014	test-auc:0.92134+0.01750
# [500]	train-auc:0.99958+0.00006	test-auc:0.92135+0.01696
# [567]	train-auc:0.99974+0.00003	test-auc:0.92115+0.01656
# [0]	train-auc:0.85999+0.00360	test-auc:0.83351+0.01172
# [100]	train-auc:0.94360+0.00437	test-auc:0.89121+0.01074
# [200]	train-auc:0.98738+0.00058	test-auc:0.91356+0.01620
# [300]	train-auc:0.99763+0.00030	test-auc:0.91852+0.02034
# [400]	train-auc:0.99916+0.00012	test-auc:0.92034+0.01975
# [500]	train-auc:0.99951+0.00007	test-auc:0.92076+0.01825
# [598]	train-auc:0.99969+0.00003	test-auc:0.92067+0.01726
# [0]	train-auc:0.86009+0.00158	test-auc:0.83199+0.01079
# [100]	train-auc:0.93804+0.00406	test-auc:0.88641+0.00930
# [200]	train-auc:0.98769+0.00134	test-auc:0.91123+0.01709
# [300]	train-auc:0.99771+0.00044	test-auc:0.91708+0.01990
# [400]	train-auc:0.99914+0.00016	test-auc:0.91945+0.01900
# [500]	train-auc:0.99952+0.00009	test-auc:0.91997+0.01725
# [580]	train-auc:0.99967+0.00007	test-auc:0.91950+0.01699
# [0]	train-auc:0.85745+0.00626	test-auc:0.83106+0.00238
# [100]	train-auc:0.93237+0.00344	test-auc:0.88003+0.01026
# [200]	train-auc:0.98707+0.00133	test-auc:0.90755+0.01779
# [300]	train-auc:0.99755+0.00045	test-auc:0.91489+0.02072
# [400]	train-auc:0.99905+0.00018	test-auc:0.91737+0.01954
# [500]	train-auc:0.99945+0.00007	test-auc:0.91768+0.01809
# [596]	train-auc:0.99965+0.00004	test-auc:0.91719+0.01770
# [0]	train-auc:0.87117+0.00549	test-auc:0.83323+0.00720
# ---------------------------------------------------------------------------
# XGBoostError                              Traceback (most recent call last)
# <ipython-input-7-bdc1aab9cd67> in <cell line: 5>()
#      19         }
#      20
# ---> 21         history = xgb.cv(
#      22             params,
#      23             dtrain,
#
# /usr/local/lib/python3.10/dist-packages/xgboost/training.py in cv(params, dtrain, num_boost_round, nfold, stratified, folds, metrics, obj, feval, maximize, early_stopping_rounds, fpreproc, as_pandas, verbose_eval, show_stdv, seed, callbacks, shuffle, custom_metric)
#     536         if callbacks_container.before_iteration(booster, i, dtrain, None):
#     537             break
# --> 538         booster.update(i, obj)
#     539
#     540         should_break = callbacks_container.after_iteration(booster, i, dtrain, None)
#
# /usr/local/lib/python3.10/dist-packages/xgboost/training.py in update(self, iteration, obj)
#     227         '''Iterate through folds for update'''
#     228         for fold in self.cvfolds:
# --> 229             fold.update(iteration, obj)
#     230
#     231     def eval(self, iteration: int, feval: Optional[Metric], output_margin: bool) -> List[str]:
#
# /usr/local/lib/python3.10/dist-packages/xgboost/training.py in update(self, iteration, fobj)
#     213     def update(self, iteration: int, fobj: Optional[Objective]) -> None:
#     214         """"Update the boosters for one iteration"""
# --> 215         self.bst.update(self.dtrain, iteration, fobj)
#     216
#     217     def eval(self, iteration: int, feval: Optional[Metric], output_margin: bool) -> str:
#
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py in update(self, dtrain, iteration, fobj)
#    1916
#    1917         if fobj is None:
# -> 1918             _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#    1919                                                     ctypes.c_int(iteration),
#    1920                                                     dtrain.handle))
#
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py in _check_call(ret)
#     277     """
#     278     if ret != 0:
# --> 279         raise XGBoostError(py_str(_LIB.XGBGetLastError()))
#     280
#     281
#
# XGBoostError: [14:03:48] ../src/tree/updater_gpu_hist.cu:802: Exception in gpu_hist: [14:03:48] ../src/c_api/../data/../common/device_helpers.cuh:431: Memory allocation error on worker 0: std::bad_alloc: cudaErrorMemoryAllocation: out of memory
# - Free memory: 2852978688
# - Requested memory: 4294967296
#
# Stack trace:
#   [bt] (0) /usr/local/lib/python3.10/dist-packages/xgboost/lib/libxgboost.so(+0x451c73) [0x7fcfcec0ec73]
#   [bt] (1) /usr/local/lib/python3.10/dist-packages/xgboost/lib/libxgboost.so(+0x456f71) [0x7fcfcec13f71]
#   [bt] (2) /usr/local/lib/python3.10/dist-packages/xgboost/lib/libxgboost.so(+0x11256f) [0x7fcfce8cf56f]
#   [bt] (3) /usr/local/lib/python3.10/dist-packages/xgboost/lib/libxgboost.so(+0x70594d) [0x7fcfceec294d]
#   [bt] (4) /usr/local/lib/python3.10/dist-packages/xgboost/lib/libxgboost.so(+0x712b30) [0x7fcfceecfb30]
#   [bt] (5) /usr/local/lib/python3.10/dist-packages/xgboost/lib/libxgboost.so(+0x712d7c) [0x7fcfceecfd7c]
#   [bt] (6) /usr/local/lib/python3.10/dist-packages/xgboost/lib/libxgboost.so(+0x713574) [0x7fcfceed0574]
#   [bt] (7) /usr/local/lib/python3.10/dist-packages/xgboost/lib/libxgboost.so(+0x719c49) [0x7fcfceed6c49]
#   [bt] (8) /usr/local/lib/python3.10/dist-packages/xgboost/lib/libxgboost.so(+0x71b021) [0x7fcfceed8021]
#
#
#
# Stack trace:
#   [bt] (0) /usr/local/lib/python3.10/dist-packages/xgboost/lib/libxgboost.so(+0x6fce83) [0x7fcfceeb9e83]
#   [bt] (1) /usr/local/lib/python3.10/dist-packages/xgboost/lib/libxgboost.so(+0x71b2b7) [0x7fcfceed82b7]
#   [bt] (2) /usr/local/lib/python3.10/dist-packages/xgboost/lib/libxgboost.so(+0x2ace51) [0x7fcfcea69e51]
#   [bt] (3) /usr/local/lib/python3.10/dist-packages/xgboost/lib/libxgboost.so(+0x2ae9e5) [0x7fcfcea6b9e5]
#   [bt] (4) /usr/local/lib/python3.10/dist-packages/xgboost/lib/libxgboost.so(+0x2e0501) [0x7fcfcea9d501]
#   [bt] (5) /usr/local/lib/python3.10/dist-packages/xgboost/lib/libxgboost.so(XGBoosterUpdateOneIter+0x70) [0x7fcfce8f95f0]
#   [bt] (6) /lib/x86_64-linux-gnu/libffi.so.7(+0x6ff5) [0x7fd02e0bbff5]
#   [bt] (7) /lib/x86_64-linux-gnu/libffi.so.7(+0x640a) [0x7fd02e0bb40a]
#   [bt] (8) /usr/lib/python3.10/lib-dynload/_ctypes.cpython-310-x86_64-linux-gnu.so(+0xc6e1) [0x7fd02e0e86e1]
