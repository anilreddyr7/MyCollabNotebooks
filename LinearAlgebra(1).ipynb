# %%
sample_vector=[1,2,3,4,5]

# %%
sample_vector[4]
# Out:
# 5

# %%
import numpy as np
np_sample_vector = np.array(sample_vector)

# %%
type(np_sample_vector)
# Out:
# numpy.ndarray

# %%
np_sample_vector.size
# Out:
# 5

# %%
np_sample_vector[0]
# Out:
# 1

# %%
import numpy as np
u = [2,5]
v = [3,1]
x_coords,y_coords = zip(u,v)

# %%
y_coords
# Out:
# (5, 1)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.scatter(x_coords,y_coords,color=['r','b'])
plt.axis([0,9,0,6])
plt.grid()
plt.show()

# %%
u = [1, 3, 5]
v = [2, 4, 6]
w = [4, 6, 8]

x_coords, y_coords, z_coords = zip(u,v,w)

# %%
x_coords
# Out:
# (1, 2, 4)

# %%
def plot_vectors3d(ax, vectors3d, z0, **options):
    for v in vectors3d:
        x, y, z = v
        ax.plot([x,x], [y,y], [z0, z], color="gray", linestyle='dotted', marker=".")
    x_coords, y_coords, z_coords = zip(*vectors3d)
    ax.scatter(x_coords, y_coords, z_coords, **options)

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline
subplot3d = plt.subplot(111, projection='3d')
#subplot3d.scatter(x_coords,y_coords,z_coords)
subplot3d.set_zlim3d([0,9])
plot_vectors3d(subplot3d,[u,v,w],0, color=("r","b","y"))
plt.show()

# %%
def len_vector(vector):
  squares = [ele**2 for ele in vector]
  return sum(squares)**0.5

# %%
new_vector = [2, 5, 6]
len_vector(new_vector)
# Out:
# 8.06225774829855

# %%
import numpy.linalg as LA
LA.norm(new_vector)
# Out:
# 8.06225774829855

# %%
np.array([2, 3]) + np.array([4, 5])
# Out:
# array([6, 8])

# %%
def get_sum(u, v):
  sum_vector = []
  if len(u)!=len(v):
    return sum_vector
  else:
    for i in range(len(u)):
      sum_vector.append(u[i]+v[i])
  return sum_vector

# %%
u = [2,3,5,5]
v = [4,5,6]
get_sum(u,v)
# Out:
# []
